# %% [markdown]
# ## Working with network protocol logs
#
# Network protocol or layer7 logs provide insight into highlevel application protocol based events.
#
# The following protocols are currently supported:
#
# - dhcp  - Zeek dhcp.log
# - dns   - Zeek dns.log
# - http  - Zeek http.log
# - sip   - Zeek sip.log
# - snmp  - Zeek snmp.log
# - ssh   - Zeek ssh.log

# %% [markdown]
# #### Start with importing some required libraries.

# %%
from datetime import datetime, timedelta

import dynamite_sdk
from dynamite_sdk.search import Search

try:
    dynamite_sdk.config.read('/etc/dynamite/dynamite_sdk/config.cfg')
except FileNotFoundError:
    print('Could not locate configuration at /etc/dynamite/dynamite_sdk/config.cfg. Please create it.')

# %% [markdown]
# #### Set our initial search window to a 60 minute timeframe.

# %%
start = datetime.now() - timedelta(minutes=240)
end = datetime.now()

# %% [markdown]
# #### Instantiate our search.Search interface to search all *dhcp* events.

# %%
search = Search('dhcp', as_dataframe=True)

# %%
search.execute_query(start, end)

# %%
search.results.head(5)
# Out:
#   event_type                       event_time source_ip_address  \
# 0       dhcp 2019-11-01 11:58:00.513000+00:00    192.168.53.158
# 1       dhcp 2019-11-01 11:30:23.249000+00:00    192.168.53.158
# 2       dhcp 2019-11-01 11:06:15.680000+00:00    192.168.53.158
# 3       dhcp 2019-11-01 10:37:37.972000+00:00    192.168.53.158
# 4       dhcp 2019-11-01 10:07:59.522000+00:00    192.168.53.158
#
#   destination_ip_address source_port destination_port     elasticsearch_index  \
# 0           192.168.32.1        None             None  dhcp-events-2019.11.01
# 1           192.168.32.1        None             None  dhcp-events-2019.11.01
# 2           192.168.32.1        None             None  dhcp-events-2019.11.01
# 3           192.168.32.1        None             None  dhcp-events-2019.11.01
# 4           192.168.32.1        None             None  dhcp-events-2019.11.01
#
#   originating_agent_tag forwarder_type node_ip_address  ... client_fqdn  \
# 0            honeypot01           zeek  192.168.53.158  ...        None
# 1            honeypot01           zeek  192.168.53.158  ...        None
# 2            honeypot01           zeek  192.168.53.158  ...        None
# 3            honeypot01           zeek  192.168.53.158  ...        None
# 4            honeypot01           zeek  192.168.53.158  ...        None
#
#                        domain requested_ip_address assigned_ip_address  \
# 0  us-west-2.compute.internal                 None      192.168.53.158
# 1  us-west-2.compute.internal                 None      192.168.53.158
# 2  us-west-2.compute.internal                 None      192.168.53.158
# 3  us-west-2.compute.internal                 None      192.168.53.158
# 4  us-west-2.compute.internal                 None      192.168.53.158
#
#   lease_time client_message server_message   message_types  duration  \
# 0     3600.0           None           None  [REQUEST, ACK]  0.000041
# 1     3600.0           None           None  [REQUEST, ACK]  0.000041
# 2     3600.0           None           None  [REQUEST, ACK]  0.000045
# 3     3600.0           None           None  [REQUEST, ACK]  0.000046
# 4     3600.0           None           None  [REQUEST, ACK]  0.000040
#
#                    uids
# 0   [CPekPVrcIKPmSTtpl]
# 1  [CXWoOw4hsk2d5JN5l8]
# 2  [C5Gyzv39JkGPnW1w32]
# 3  [COQz9I21f6MRpCctll]
# 4  [CLbAwM2lKdl6qdsJ09]
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Instantiate our search.Search interface to search all *dns* events.

# %%
search = Search('dns', as_dataframe=True)

# %%
search.execute_query(start, end)
# Out:
# 4 dns-events** failed to parse.

# %%
search.results.head(5)
# Out:
#   event_type                       event_time source_ip_address  \
# 0        dns 2019-11-01 12:05:58.375000+00:00    192.168.53.158
# 1        dns 2019-11-01 12:00:03.018000+00:00    192.168.53.158
# 2        dns 2019-11-01 12:00:01.970000+00:00    192.168.53.158
# 3        dns 2019-11-01 12:00:01.777000+00:00    192.168.53.158
# 4        dns 2019-11-01 11:53:15.716000+00:00    192.168.53.158
#
#   destination_ip_address  source_port  destination_port  \
# 0            192.168.0.2        41804                53
# 1            192.168.0.2        54097                53
# 2            192.168.0.2        33768                53
# 3            192.168.0.2        50820                53
# 4            192.168.0.2        46783                53
#
#      elasticsearch_index originating_agent_tag forwarder_type node_ip_address  \
# 0  dns-events-2019.11.01            honeypot01           zeek  192.168.53.158
# 1  dns-events-2019.11.01            honeypot01           zeek  192.168.53.158
# 2  dns-events-2019.11.01            honeypot01           zeek  192.168.53.158
# 3  dns-events-2019.11.01            honeypot01           zeek  192.168.53.158
# 4  dns-events-2019.11.01            honeypot01           zeek  192.168.53.158
#
#    ...               answers  query_type  query_type_name  query_class  \
# 0  ...                  None          12              PTR            1
# 1  ...                  None          12              PTR            1
# 2  ...                  None          12              PTR            1
# 3  ...  [h140-112.fcsrv.net]          12              PTR            1
# 4  ...                  None           1                A            1
#
#    query_class_name                                              query  \
# 0        C_INTERNET                         129.194.40.45.in-addr.arpa
# 1        C_INTERNET                          150.45.22.81.in-addr.arpa
# 2        C_INTERNET                        110.27.176.185.in-addr.arpa
# 3        C_INTERNET                        140.112.28.194.in-addr.arpa
# 4        C_INTERNET  97-68-93-237.biz.bhn.net.us-west-2.compute.int...
#
#   response_code  response_code_name transaction_id  round_trip_time
# 0             3            NXDOMAIN          64143             None
# 1             3            NXDOMAIN          49750             None
# 2             3            NXDOMAIN          44664             None
# 3             0             NOERROR          32991          0.18617
# 4             3            NXDOMAIN          10767             None
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Instantiate our search.Search interface to search all *http* events.

# %%
search = Search('http', as_dataframe=True)

# %%
search.execute_query(start, end)

# %%
search.results.head(5)
# Out:
#   event_type                       event_time source_ip_address  \
# 0       http 2019-11-01 12:01:44.500000+00:00    192.168.53.158
# 1       http 2019-11-01 11:58:00.795000+00:00    192.168.53.158
# 2       http 2019-11-01 11:30:23.520000+00:00    192.168.53.158
# 3       http 2019-11-01 11:06:15.951000+00:00    192.168.53.158
# 4       http 2019-11-01 11:01:44.499000+00:00    192.168.53.158
#
#   destination_ip_address  source_port  destination_port  \
# 0        169.254.169.254        50972                80
# 1        169.254.169.254        50970                80
# 2        169.254.169.254        50968                80
# 3        169.254.169.254        50966                80
# 4        169.254.169.254        50964                80
#
#       elasticsearch_index originating_agent_tag forwarder_type  \
# 0  http-events-2019.11.01            honeypot01           zeek
# 1  http-events-2019.11.01            honeypot01           zeek
# 2  http-events-2019.11.01            honeypot01           zeek
# 3  http-events-2019.11.01            honeypot01           zeek
# 4  http-events-2019.11.01            honeypot01           zeek
#
#   node_ip_address  ... originating_fuids  originating_filenames  \
# 0  192.168.53.158  ...              None                   None
# 1  192.168.53.158  ...              None                   None
# 2  192.168.53.158  ...              None                   None
# 3  192.168.53.158  ...              None                   None
# 4  192.168.53.158  ...              None                   None
#
#   originating_mime_types       recipient_fuids recipient_filenames  \
# 0                   None  [FxA22o1v0uBIS4opc7]                None
# 1                   None  [FKM5eM18mBfFylctt4]                None
# 2                   None  [Fwqw2A1MsSjb3owrYb]                None
# 3                   None  [FOr8mE3kLIdkzRZgb5]                None
# 4                   None  [FL3dRO1Mp22qK0zOef]                None
#
#   recipient_mime_types                  client_header_names  \
# 0          [text/html]  [HOST, USER-AGENT, ACCEPT-ENCODING]
# 1         [text/plain]           [HOST, USER-AGENT, ACCEPT]
# 2         [text/plain]           [HOST, USER-AGENT, ACCEPT]
# 3         [text/plain]           [HOST, USER-AGENT, ACCEPT]
# 4          [text/html]  [HOST, USER-AGENT, ACCEPT-ENCODING]
#
#   server_header_names cookie_variables  uri_variables
# 0                None             None           None
# 1                None             None           None
# 2                None             None           None
# 3                None             None           None
# 4                None             None           None
#
# [5 rows x 38 columns]

# %% [markdown]
# #### Instantiate our search.Search interface to search all *sip* events.

# %%
search = Search('sip', as_dataframe=True)

# %%
search.execute_query(start, end)

# %%
search.results.head(10)
# Out:
#   event_type                       event_time source_ip_address  \
# 0        sip 2019-11-01 11:32:07.038000+00:00     77.247.110.61
# 1        sip 2019-11-01 11:22:04.802000+00:00      183.2.202.41
# 2        sip 2019-11-01 10:00:19.257000+00:00    77.247.110.162
# 3        sip 2019-11-01 09:38:27.481000+00:00    77.247.108.162
# 4        sip 2019-11-01 09:31:50.381000+00:00      183.2.202.41
#
#   destination_ip_address  source_port  destination_port  \
# 0         192.168.53.158         5081              5060
# 1         192.168.53.158         5061              5060
# 2         192.168.53.158         5256             15061
# 3         192.168.53.158         5077              1028
# 4         192.168.53.158         5061              5060
#
#      elasticsearch_index originating_agent_tag forwarder_type node_ip_address  \
# 0  sip-events-2019.11.01            honeypot01           zeek  192.168.53.158
# 1  sip-events-2019.11.01            honeypot01           zeek  192.168.53.158
# 2  sip-events-2019.11.01            honeypot01           zeek  192.168.53.158
# 3  sip-events-2019.11.01            honeypot01           zeek  192.168.53.158
# 4  sip-events-2019.11.01            honeypot01           zeek  192.168.53.158
#
#    ... subject                       request_path response_path  \
# 0  ...    None   [SIP/2.0/UDP 77.247.110.61:5081]            []
# 1  ...    None    [SIP/2.0/UDP 192.168.0.42:5061]            []
# 2  ...    None  [SIP/2.0/UDP 77.247.110.162:5256]            []
# 3  ...    None  [SIP/2.0/UDP 77.247.108.162:5077]            []
# 4  ...    None    [SIP/2.0/UDP 192.168.0.42:5061]            []
#
#          user_agent status_code status_message warning request_body_length  \
# 0  friendly-scanner        None           None    None                   0
# 1  friendly-scanner        None           None    None                   0
# 2           eyeBeam        None           None    None                   0
# 3  friendly-scanner        None           None    None                   0
# 4  friendly-scanner        None           None    None                   0
#
#   response_body_length content_type
# 0                 None         None
# 1                 None         None
# 2                 None         None
# 3                 None         None
# 4                 None         None
#
# [5 rows x 31 columns]

# %% [markdown]
# #### Instantiate our search.Search interface to search all *snmp* events.

# %%
search = Search('snmp', as_dataframe=True)

# %%
search.execute_query(start, end)

# %%
search.results.head(5)
# Out:
#   event_type                       event_time source_ip_address  \
# 0       snmp 2019-11-01 08:19:45.957000+00:00      185.94.111.1
#
#   destination_ip_address  source_port  destination_port  \
# 0         192.168.53.158        50613               161
#
#       elasticsearch_index originating_agent_tag forwarder_type  \
# 0  snmp-events-2019.11.01            honeypot01           zeek
#
#   node_ip_address                                 node_hostname  duration  \
# 0  192.168.53.158  ip-192-168-53-158.us-west-2.compute.internal       0.0
#
#   version community_string  get_requests  get_bulk_requests  get_responses  \
# 0      2c           public             0                  1              0
#
#    set_requests display_string up_since
# 0             0           None     None

# %% [markdown]
# #### Instantiate our search.Search interface to search all *ssh* events.

# %%
search = Search('ssh', as_dataframe=True)

# %%
search.execute_query(start, end)

# %%
search.results.head(5)
# Out:
#   event_type                       event_time source_ip_address  \
# 0        ssh 2019-11-01 12:05:55.311000+00:00     45.40.194.129
# 1        ssh 2019-11-01 12:02:48.949000+00:00    138.186.62.138
# 2        ssh 2019-11-01 11:53:14.987000+00:00      97.68.93.237
# 3        ssh 2019-11-01 11:40:12.243000+00:00     49.234.116.13
# 4        ssh 2019-11-01 11:36:45.194000+00:00    132.232.43.115
#
#   destination_ip_address  source_port  destination_port  \
# 0         192.168.53.158        46602                22
# 1         192.168.53.158        53378                22
# 2         192.168.53.158        49468                22
# 3         192.168.53.158        47720                22
# 4         192.168.53.158        57760                22
#
#      elasticsearch_index originating_agent_tag forwarder_type node_ip_address  \
# 0  ssh-events-2019.11.01            honeypot01           zeek  192.168.53.158
# 1  ssh-events-2019.11.01            honeypot01           zeek  192.168.53.158
# 2  ssh-events-2019.11.01            honeypot01           zeek  192.168.53.158
# 3  ssh-events-2019.11.01            honeypot01           zeek  192.168.53.158
# 4  ssh-events-2019.11.01            honeypot01           zeek  192.168.53.158
#
#    ... authentication_attempts direction client_version_string  \
# 0  ...                       0   INBOUND  -HSS2.0-libssh-0.6.3
# 1  ...                       0   INBOUND  SSH-2.0-libssh-0.6.3
# 2  ...                       0   INBOUND  SSH-2.0-libssh-0.6.3
# 3  ...                       0   INBOUND  -HSS2.0-libssh-0.6.3
# 4  ...                       0   INBOUND  SSH-2.0-libssh-0.6.3
#
#    server_version_string cipher_algorithm mac_algorithm compression_algorithm  \
# 0    SSH-2.0-OpenSSH_7.4             None          None                  None
# 1    SSH-2.0-OpenSSH_7.4             None          None                  None
# 2    SSH-2.0-OpenSSH_7.4       aes256-ctr     hmac-sha1                  none
# 3    SSH-2.0-OpenSSH_7.4       aes256-ctr     hmac-sha1                  none
# 4    SSH-2.0-OpenSSH_7.4       aes256-ctr     hmac-sha1                  none
#
#   key_algorithm   host_key_algorithm  \
# 0          None                 None
# 1          None                 None
# 2          None  ecdsa-sha2-nistp256
# 3          None  ecdsa-sha2-nistp256
# 4          None  ecdsa-sha2-nistp256
#
#                                           host_key
# 0                                             None
# 1                                             None
# 2  0d:90:76:bf:3b:89:6e:fc:7c:6e:a9:ba:71:26:8a:4d
# 3  0d:90:76:bf:3b:89:6e:fc:7c:6e:a9:ba:71:26:8a:4d
# 4  0d:90:76:bf:3b:89:6e:fc:7c:6e:a9:ba:71:26:8a:4d
#
# [5 rows x 23 columns]
